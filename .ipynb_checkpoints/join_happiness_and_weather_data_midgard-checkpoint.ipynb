# %% [markdown]
# # PART 3

# %%
from pymongo import MongoClient
import pandas as pd

def query_to_dataframe(query, database):
    '''
    custom function to create a dataframe of query results
    from a mongodb database
    '''
    
    client = MongoClient(host="midgard09", port=27017)
    weather_data = client.pitds_weather_data[database]
    
    entries = []
    for entry in weather_data.find(query):
        entries.append(entry)
      
    if len(entries)==0: # no hits for the query
        return None
    else:
        return pd.DataFrame(entries).drop(columns=["_id"])

# %%
# Get happiness data
happiness = query_to_dataframe({}, database="happiness_data")

# Get 2018 weather data
weather_2018 = pd.read_excel("cleaned_2018_data.xlsx")

# Get station locations
stations = query_to_dataframe({}, database="station_cordinates")

# %%
happiness
# Out:
#    area_codes                area_names  avg_rating  high_7_8  latitude  \
# 0   E12000001                NORTH EAST        7.34     39.06      55.0
# 1   E12000002               NORTH WEST         7.39     39.10      54.0
# 2   E12000003  YORKSHIRE AND THE HUMBER        7.41     38.56      53.6
# 3   E12000004             EAST MIDLANDS        7.51     38.62      53.0
# 4   E12000005             WEST MIDLANDS        7.43     41.72      52.5
# 5   E12000006                      EAST        7.51     41.69      52.2
# 6   E12000007                    LONDON        7.38     42.20      51.5
# 7   E12000008                SOUTH EAST        7.54     40.88      51.3
# 8   E12000009                SOUTH WEST        7.50     40.44      51.0
# 9   W92000004                     WALES        7.44     39.45      51.5
# 10  S92000003                  SCOTLAND        7.45     39.75      56.0
# 11  N92000002         NORTHERN IRELAND5        7.75     37.57      54.6
#
#     longitude  low_0_4  medium_5_6  sample_size  vhigh_9_10
# 0        -1.9    10.77       17.05        11310       33.13
# 1        -2.6    10.17       16.82        19460       33.91
# 2        -1.2    10.21       16.60        13110       34.63
# 3        -0.8     8.66       16.74         7880       35.99
# 4        -2.3     8.61       17.59        11940       32.08
# 5         0.4     8.53       15.69         9960       34.09
# 6        -0.1     8.32       18.30        13560       31.18
# 7        -0.5     7.97       15.83        19490       35.32
# 8        -3.2     8.79       15.92        13600       34.84
# 9        -3.2     9.56       16.54        19540       34.45
# 10       -3.2     9.16       16.90        22760       34.19
# 11        5.9     6.76       14.66         2540       41.00

# %%
weather_2018.head()
# Out:
#    af_days  month  rain_mm station_name  sun_hours  tmax_degC  tmin_degC  year
# 0        0      1    117.2    aberporth       53.5        8.4        3.8  2018
# 1       10      2     48.6    aberporth       91.3        6.3        1.3  2018
# 2        6      3     97.0    aberporth      100.6        7.7        2.3  2018
# 3        0      4     70.6    aberporth      152.2       12.1        6.4  2018
# 4        0      5     33.4    aberporth      219.4       15.3        8.1  2018

# %%
#weather_2018.drop(columns=["Unnamed: 0"], inplace=True)
weather_2018.head()
# Out:
#    af_days  month  rain_mm station_name  sun_hours  tmax_degC  tmin_degC  year
# 0        0      1    117.2    aberporth       53.5        8.4        3.8  2018
# 1       10      2     48.6    aberporth       91.3        6.3        1.3  2018
# 2        6      3     97.0    aberporth      100.6        7.7        2.3  2018
# 3        0      4     70.6    aberporth      152.2       12.1        6.4  2018
# 4        0      5     33.4    aberporth      219.4       15.3        8.1  2018

# %%
stations = stations.set_index("station").drop(columns=["label"])
stations.head()
# Out:
#               latitude  longitude
# station
# aberporth       52.139     -4.570
# armagh          54.352     -6.649
# ballypatrick    55.181     -6.153
# bradford        53.813     -1.772
# braemar         57.006     -3.396

# %% [markdown]
# ### Join stations and happiness data

# %%
import numpy as np

def square(x):
    return x*x

def get_shortest_distance(a, b):
    x = b.longitude - a.longitude
    y = b.latitude - a.latitude
    
    xx = x.apply(func=square)
    yy = y.apply(func=square)
    
    return np.sqrt(xx+yy).sort_values().index[0]
     
    
def get_area_index(station, stations, areas):
    '''
    custom function to identify the area to which a given station belongs.
    The fucntion chooses the area that has the least straight line distance from
    the station. The straight line distance betwen a stationa an area is determined 
    using the coordiates of the station and the coordinate sof the area.
    
    param: station - the name of the station on interest
    param: stations - the names and locations of all stations
    param: areas - the names and locations of all stations
    
    return: area - the name of the closest area
    '''
    from_location = stations.loc[station]
    index = get_shortest_distance(a=from_location, b=areas)
    
    return areas.index[index]


def get_nearest_area(station, stations, happiness):
    
    h = happiness.copy(deep=True)
    areas = pd.concat([h.area_codes, h.latitude, h.longitude], axis=1)
    
    return h.area_codes.loc[get_area_index(station, stations, areas)]

# %%
get_nearest_area("ballypatrick", stations, happiness)
# Out:
# 'S92000003'

# %%
areas = []
for station in stations.index:
    area = get_nearest_area(station, stations, happiness)
    areas.append(area)
    
station_area = pd.concat([pd.Series(stations.index), pd.Series(areas, name="area")], axis=1)
station_area
# Out:
#             station       area
# 0         aberporth  W92000004
# 1            armagh  S92000003
# 2      ballypatrick  S92000003
# 3          bradford  E12000003
# 4           braemar  S92000003
# 5          camborne  E12000009
# 6         cambridge  E12000006
# 7           cardiff  W92000004
# 8          chivenor  E12000009
# 9        cwmystwyth  W92000004
# 10     dunstaffnage  S92000003
# 11           durham  E12000001
# 12       eastbourne  E12000007
# 13      eskdalemuir  S92000003
# 14         heathrow  E12000008
# 15             hurn  E12000009
# 16          lerwick  S92000003
# 17         leuchars  S92000003
# 18        lowestoft  E12000006
# 19          manston  E12000006
# 20            nairn  S92000003
# 21       newtonrigg  E12000002
# 22           oxford  E12000008
# 23          paisley  S92000003
# 24          ringway  E12000002
# 25        rossonwye  E12000005
# 26         shawbury  E12000005
# 27        sheffield  E12000003
# 28      southampton  E12000008
# 29        stornoway  S92000003
# 30  suttonbonington  E12000004
# 31            tiree  S92000003
# 32           valley  E12000002
# 33       waddington  E12000004
# 34           whitby  E12000003
# 35      wickairport  S92000003
# 36        yeovilton  E12000009

# %%
station_area[:18]
# Out:
#          station       area
# 0      aberporth  W92000004
# 1         armagh  S92000003
# 2   ballypatrick  S92000003
# 3       bradford  E12000003
# 4        braemar  S92000003
# 5       camborne  E12000009
# 6      cambridge  E12000006
# 7        cardiff  W92000004
# 8       chivenor  E12000009
# 9     cwmystwyth  W92000004
# 10  dunstaffnage  S92000003
# 11        durham  E12000001
# 12    eastbourne  E12000007
# 13   eskdalemuir  S92000003
# 14      heathrow  E12000008
# 15          hurn  E12000009
# 16       lerwick  S92000003
# 17      leuchars  S92000003

# %%
station_area.area.unique()
# Out:
# array(['W92000004', 'S92000003', 'E12000003', 'E12000009', 'E12000006',
#        'E12000001', 'E12000007', 'E12000008', 'E12000002', 'E12000005',
#        'E12000004'], dtype=object)

# %% [markdown]
# ### merge station_area with averaged weather data

# %%
def get_season_average(months, data):
    
    season = data[data.month == months[0]]
    season = season.set_index("station_name")
    
    # cummulatively sum up data for each month
    for month in range(1, len(months)):
        season = season + data[data.month == months[month]].set_index("station_name")
    
    season.drop(columns=["month","year"], inplace=True) # drop meaningless averages
    
    # divide by the number of months to return averages
    return season/len(months)


# Get averages for the whole year
w_2018_avg = get_season_average(months=[i for i in range(1,13)], data=weather_2018)

# %%
w_2018_avg.head()
# Out:
#                 af_days     rain_mm   sun_hours  tmax_degC  tmin_degC
# station_name
# aberporth      1.333333   83.683333  132.400000  13.166667   7.683333
# armagh         2.750000   67.458333  114.141667  13.650000   6.033333
# ballypatrick   2.166667  103.833333   35.252778  11.841667   6.016667
# bradford       3.333333   58.483333  126.133333  13.741667   6.366667
# braemar       10.083333   71.308333   29.852778  11.208333   2.908333

# %%
# Join weather and area data
weather_area = pd.concat([w_2018_avg, station_area.set_index("station")], axis=1, sort=True)
weather_area
# Out:
#                    af_days     rain_mm   sun_hours  tmax_degC  tmin_degC  \
# aberporth         1.333333   83.683333  132.400000  13.166667   7.683333
# armagh            2.750000   67.458333  114.141667  13.650000   6.033333
# ballypatrick      2.166667  103.833333   35.252778  11.841667   6.016667
# bradford          3.333333   58.483333  126.133333  13.741667   6.366667
# braemar          10.083333   71.308333   29.852778  11.208333   2.908333
# camborne          0.833333   99.683333  126.883333  14.241667   8.825000
# cambridge         2.916667   41.483333   41.833333  15.425000   6.800000
# cardiff           2.833333   99.300000   39.819444  15.433333   7.575000
# chivenor          1.833333   69.116667   43.766667  15.200000   8.175000
# cwmystwyth             NaN         NaN         NaN        NaN        NaN
# dunstaffnage      2.333333  143.941667   32.313889  12.983333   6.425000
# durham            4.083333   50.375000   37.355556  13.708333   5.908333
# eastbourne        1.000000   68.800000  171.616667  15.016667   8.841667
# eskdalemuir       7.000000  146.308333   94.375000  11.708333   4.016667
# heathrow          1.916667   48.333333  142.066667  16.625000   8.300000
# hurn              4.166667   68.725000  151.483333  15.916667   6.558333
# lerwick           2.250000   88.875000  104.525000  10.083333   5.741667
# leuchars          5.000000   54.191667  132.191667  12.883333   5.316667
# lowestoft         2.083333   47.400000  162.933333  14.483333   7.775000
# manston           1.416667   55.925000  158.566667  14.825000   7.991667
# nairn             5.583333   41.775000  143.700000  12.750000   5.025000
# newtonrigg        5.250000   74.866667   32.344444  13.066667   5.041667
# oxford            2.666667   50.516667  150.141667  15.616667   7.450000
# paisley           3.750000   90.433333  120.016667  13.050000   6.116667
# ringway                NaN         NaN         NaN        NaN        NaN
# rossonwye         3.083333   62.541667  142.766667  15.391667   6.983333
# shawbury          4.416667   52.766667  125.158333  14.583333   6.025000
# sheffield         2.000000   66.516667  126.475000  14.391667   7.233333
# southampton            NaN         NaN         NaN        NaN        NaN
# stornoway         2.416667   96.816667  104.466667  11.541667   6.058333
# suttonbonington   2.833333   44.683333   40.402778  15.000000   6.916667
# tiree             1.000000  102.475000  121.425000  11.925000   6.908333
# valley            2.000000   72.766667  138.883333  13.641667   7.908333
# waddington        2.833333   49.475000  134.766667  14.516667   6.908333
# whitby            2.416667   51.275000  139.250000  13.741667   6.775000
# wickairport       3.083333   49.550000   38.244444  11.300000   5.583333
# yeovilton         3.333333   56.750000  133.300000  15.791667   6.958333
#
#                       area
# aberporth        W92000004
# armagh           S92000003
# ballypatrick     S92000003
# bradford         E12000003
# braemar          S92000003
# camborne         E12000009
# cambridge        E12000006
# cardiff          W92000004
# chivenor         E12000009
# cwmystwyth       W92000004
# dunstaffnage     S92000003
# durham           E12000001
# eastbourne       E12000007
# eskdalemuir      S92000003
# heathrow         E12000008
# hurn             E12000009
# lerwick          S92000003
# leuchars         S92000003
# lowestoft        E12000006
# manston          E12000006
# nairn            S92000003
# newtonrigg       E12000002
# oxford           E12000008
# paisley          S92000003
# ringway          E12000002
# rossonwye        E12000005
# shawbury         E12000005
# sheffield        E12000003
# southampton      E12000008
# stornoway        S92000003
# suttonbonington  E12000004
# tiree            S92000003
# valley           E12000002
# waddington       E12000004
# whitby           E12000003
# wickairport      S92000003
# yeovilton        E12000009

# %% [markdown]
# ## store weather_area in database

# %%
weather_area.reset_index(inplace=True)
weather_area.rename(columns={"index":"station"}, inplace=True)
weather_area.head()
# Out:
#         station    af_days     rain_mm   sun_hours  tmax_degC  tmin_degC  \
# 0     aberporth   1.333333   83.683333  132.400000  13.166667   7.683333
# 1        armagh   2.750000   67.458333  114.141667  13.650000   6.033333
# 2  ballypatrick   2.166667  103.833333   35.252778  11.841667   6.016667
# 3      bradford   3.333333   58.483333  126.133333  13.741667   6.366667
# 4       braemar  10.083333   71.308333   29.852778  11.208333   2.908333
#
#         area
# 0  W92000004
# 1  S92000003
# 2  S92000003
# 3  E12000003
# 4  S92000003

# %%
from pymongo import MongoClient

def make_lineObj(line, data):
    ''' create a dict object of a specified row
        of a dataframe
    '''

    obj = {}
    
    for column in data.columns:
        obj[column] = data[column].iloc[line]
        
    return obj

def storeObj(obj):
    
    collection = "weather_area_data"
    
    # Config database server
    client = MongoClient(host="midgard09", port=27017)
    db = client.pitds_weather_data
    weather_data = db[collection]
    
    # Store document
    weather_data.insert_one(obj)
    print("successfully stored: ", obj["area"])
    
    
for row in range(0, len(weather_area)):
    storeObj(make_lineObj(row, weather_area))
# Out:
# successfully stored:  W92000004
# successfully stored:  S92000003
# successfully stored:  S92000003
# successfully stored:  E12000003
# successfully stored:  S92000003
# successfully stored:  E12000009
# successfully stored:  E12000006
# successfully stored:  W92000004
# successfully stored:  E12000009
# successfully stored:  W92000004
# successfully stored:  S92000003
# successfully stored:  E12000001
# successfully stored:  E12000007
# successfully stored:  S92000003
# successfully stored:  E12000008
# successfully stored:  E12000009
# successfully stored:  S92000003
# successfully stored:  S92000003
# successfully stored:  E12000006
# successfully stored:  E12000006
# successfully stored:  S92000003
# successfully stored:  E12000002
# successfully stored:  E12000008
# successfully stored:  S92000003
# successfully stored:  E12000002
# successfully stored:  E12000005
# successfully stored:  E12000005
# successfully stored:  E12000003
# successfully stored:  E12000008
# successfully stored:  S92000003
# successfully stored:  E12000004
# successfully stored:  S92000003
# successfully stored:  E12000002
# successfully stored:  E12000004
# successfully stored:  E12000003
# successfully stored:  S92000003
# successfully stored:  E12000009

# %% [markdown]
# # use mongodb aggregation to join the weather and happiness data

# %%
def flatten(aggregate_obj, to_extract):
    '''
    Custom function to flatten a nested dictionary that
    results from a mongodb aggregation.
    '''
    # Extracct nested entires
    extract = aggregate_obj[to_extract][0]
    
    # discard redundant dict items
    aggregate_obj.pop(to_extract)
    aggregate_obj.pop("_id")
    extract.pop("_id")
    
    # return flattened dictionary
    return {**aggregate_obj, **extract}
    
    
def aggregation_to_dataframe(query, database):
    '''
    Custom function that returns the results of a mongodb 
    aggregation in a dataframe
    '''
    
    # config database
    client = MongoClient(host="midgard09", port=27017)
    weather_data = client.pitds_weather_data[database]
    
    entries = []
    
    # collect entries
    for entry in weather_data.aggregate(query):
        
        flat_entry = flatten(aggregate_obj=entry, to_extract="happiness")
        entries.append(flat_entry)
        
    #create dataframe
    return pd.DataFrame(entries)

# %%
# specify aggregation details
query = [{
          '$lookup': {
            'from': 'happiness_data', 
            'localField': 'area', 
            'foreignField': 'area_codes', 
            'as': 'happiness'
          }
        }
       ]

database = "weather_area_data"

# Join weather and happiness data
joined = aggregation_to_dataframe(query, database)
joined.head()
# Out:
#      af_days       area area_codes                area_names  avg_rating  \
# 0   1.333333  W92000004  W92000004                     WALES        7.44
# 1   2.750000  S92000003  S92000003                  SCOTLAND        7.45
# 2   2.166667  S92000003  S92000003                  SCOTLAND        7.45
# 3   3.333333  E12000003  E12000003  YORKSHIRE AND THE HUMBER        7.41
# 4  10.083333  S92000003  S92000003                  SCOTLAND        7.45
#
#    high_7_8  latitude  longitude  low_0_4  medium_5_6     rain_mm  \
# 0     39.45      51.5       -3.2     9.56       16.54   83.683333
# 1     39.75      56.0       -3.2     9.16       16.90   67.458333
# 2     39.75      56.0       -3.2     9.16       16.90  103.833333
# 3     38.56      53.6       -1.2    10.21       16.60   58.483333
# 4     39.75      56.0       -3.2     9.16       16.90   71.308333
#
#    sample_size       station   sun_hours  tmax_degC  tmin_degC  vhigh_9_10
# 0        19540     aberporth  132.400000  13.166667   7.683333       34.45
# 1        22760        armagh  114.141667  13.650000   6.033333       34.19
# 2        22760  ballypatrick   35.252778  11.841667   6.016667       34.19
# 3        13110      bradford  126.133333  13.741667   6.366667       34.63
# 4        22760       braemar   29.852778  11.208333   2.908333       34.19

# %%
# Drop repeated column that was used for joining
joined.drop(columns=["area"], inplace=True)
cols = ["area_codes", "area_names","station", "latitude", "longitude",
       "low_0_4","medium_5_6", "high_7_8","vhigh_9_10", "avg_rating",
       "af_days", "rain_mm", "sun_hours" , "tmax_degC","tmin_degC"]
joined[cols]
# Out:
#    area_codes                area_names          station  latitude  longitude  \
# 0   W92000004                     WALES        aberporth      51.5       -3.2
# 1   S92000003                  SCOTLAND           armagh      56.0       -3.2
# 2   S92000003                  SCOTLAND     ballypatrick      56.0       -3.2
# 3   E12000003  YORKSHIRE AND THE HUMBER         bradford      53.6       -1.2
# 4   S92000003                  SCOTLAND          braemar      56.0       -3.2
# 5   E12000009                SOUTH WEST         camborne      51.0       -3.2
# 6   E12000006                      EAST        cambridge      52.2        0.4
# 7   W92000004                     WALES          cardiff      51.5       -3.2
# 8   E12000009                SOUTH WEST         chivenor      51.0       -3.2
# 9   W92000004                     WALES       cwmystwyth      51.5       -3.2
# 10  S92000003                  SCOTLAND     dunstaffnage      56.0       -3.2
# 11  E12000001                NORTH EAST           durham      55.0       -1.9
# 12  E12000007                    LONDON       eastbourne      51.5       -0.1
# 13  S92000003                  SCOTLAND      eskdalemuir      56.0       -3.2
# 14  E12000008                SOUTH EAST         heathrow      51.3       -0.5
# 15  E12000009                SOUTH WEST             hurn      51.0       -3.2
# 16  S92000003                  SCOTLAND          lerwick      56.0       -3.2
# 17  S92000003                  SCOTLAND         leuchars      56.0       -3.2
# 18  E12000006                      EAST        lowestoft      52.2        0.4
# 19  E12000006                      EAST          manston      52.2        0.4
# 20  S92000003                  SCOTLAND            nairn      56.0       -3.2
# 21  E12000002               NORTH WEST        newtonrigg      54.0       -2.6
# 22  E12000008                SOUTH EAST           oxford      51.3       -0.5
# 23  S92000003                  SCOTLAND          paisley      56.0       -3.2
# 24  E12000002               NORTH WEST           ringway      54.0       -2.6
# 25  E12000005             WEST MIDLANDS        rossonwye      52.5       -2.3
# 26  E12000005             WEST MIDLANDS         shawbury      52.5       -2.3
# 27  E12000003  YORKSHIRE AND THE HUMBER        sheffield      53.6       -1.2
# 28  E12000008                SOUTH EAST      southampton      51.3       -0.5
# 29  S92000003                  SCOTLAND        stornoway      56.0       -3.2
# 30  E12000004             EAST MIDLANDS  suttonbonington      53.0       -0.8
# 31  S92000003                  SCOTLAND            tiree      56.0       -3.2
# 32  E12000002               NORTH WEST            valley      54.0       -2.6
# 33  E12000004             EAST MIDLANDS       waddington      53.0       -0.8
# 34  E12000003  YORKSHIRE AND THE HUMBER           whitby      53.6       -1.2
# 35  S92000003                  SCOTLAND      wickairport      56.0       -3.2
# 36  E12000009                SOUTH WEST        yeovilton      51.0       -3.2
#
#     low_0_4  medium_5_6  high_7_8  vhigh_9_10  avg_rating    af_days  \
# 0      9.56       16.54     39.45       34.45        7.44   1.333333
# 1      9.16       16.90     39.75       34.19        7.45   2.750000
# 2      9.16       16.90     39.75       34.19        7.45   2.166667
# 3     10.21       16.60     38.56       34.63        7.41   3.333333
# 4      9.16       16.90     39.75       34.19        7.45  10.083333
# 5      8.79       15.92     40.44       34.84        7.50   0.833333
# 6      8.53       15.69     41.69       34.09        7.51   2.916667
# 7      9.56       16.54     39.45       34.45        7.44   2.833333
# 8      8.79       15.92     40.44       34.84        7.50   1.833333
# 9      9.56       16.54     39.45       34.45        7.44        NaN
# 10     9.16       16.90     39.75       34.19        7.45   2.333333
# 11    10.77       17.05     39.06       33.13        7.34   4.083333
# 12     8.32       18.30     42.20       31.18        7.38   1.000000
# 13     9.16       16.90     39.75       34.19        7.45   7.000000
# 14     7.97       15.83     40.88       35.32        7.54   1.916667
# 15     8.79       15.92     40.44       34.84        7.50   4.166667
# 16     9.16       16.90     39.75       34.19        7.45   2.250000
# 17     9.16       16.90     39.75       34.19        7.45   5.000000
# 18     8.53       15.69     41.69       34.09        7.51   2.083333
# 19     8.53       15.69     41.69       34.09        7.51   1.416667
# 20     9.16       16.90     39.75       34.19        7.45   5.583333
# 21    10.17       16.82     39.10       33.91        7.39   5.250000
# 22     7.97       15.83     40.88       35.32        7.54   2.666667
# 23     9.16       16.90     39.75       34.19        7.45   3.750000
# 24    10.17       16.82     39.10       33.91        7.39        NaN
# 25     8.61       17.59     41.72       32.08        7.43   3.083333
# 26     8.61       17.59     41.72       32.08        7.43   4.416667
# 27    10.21       16.60     38.56       34.63        7.41   2.000000
# 28     7.97       15.83     40.88       35.32        7.54        NaN
# 29     9.16       16.90     39.75       34.19        7.45   2.416667
# 30     8.66       16.74     38.62       35.99        7.51   2.833333
# 31     9.16       16.90     39.75       34.19        7.45   1.000000
# 32    10.17       16.82     39.10       33.91        7.39   2.000000
# 33     8.66       16.74     38.62       35.99        7.51   2.833333
# 34    10.21       16.60     38.56       34.63        7.41   2.416667
# 35     9.16       16.90     39.75       34.19        7.45   3.083333
# 36     8.79       15.92     40.44       34.84        7.50   3.333333
#
#        rain_mm   sun_hours  tmax_degC  tmin_degC
# 0    83.683333  132.400000  13.166667   7.683333
# 1    67.458333  114.141667  13.650000   6.033333
# 2   103.833333   35.252778  11.841667   6.016667
# 3    58.483333  126.133333  13.741667   6.366667
# 4    71.308333   29.852778  11.208333   2.908333
# 5    99.683333  126.883333  14.241667   8.825000
# 6    41.483333   41.833333  15.425000   6.800000
# 7    99.300000   39.819444  15.433333   7.575000
# 8    69.116667   43.766667  15.200000   8.175000
# 9          NaN         NaN        NaN        NaN
# 10  143.941667   32.313889  12.983333   6.425000
# 11   50.375000   37.355556  13.708333   5.908333
# 12   68.800000  171.616667  15.016667   8.841667
# 13  146.308333   94.375000  11.708333   4.016667
# 14   48.333333  142.066667  16.625000   8.300000
# 15   68.725000  151.483333  15.916667   6.558333
# 16   88.875000  104.525000  10.083333   5.741667
# 17   54.191667  132.191667  12.883333   5.316667
# 18   47.400000  162.933333  14.483333   7.775000
# 19   55.925000  158.566667  14.825000   7.991667
# 20   41.775000  143.700000  12.750000   5.025000
# 21   74.866667   32.344444  13.066667   5.041667
# 22   50.516667  150.141667  15.616667   7.450000
# 23   90.433333  120.016667  13.050000   6.116667
# 24         NaN         NaN        NaN        NaN
# 25   62.541667  142.766667  15.391667   6.983333
# 26   52.766667  125.158333  14.583333   6.025000
# 27   66.516667  126.475000  14.391667   7.233333
# 28         NaN         NaN        NaN        NaN
# 29   96.816667  104.466667  11.541667   6.058333
# 30   44.683333   40.402778  15.000000   6.916667
# 31  102.475000  121.425000  11.925000   6.908333
# 32   72.766667  138.883333  13.641667   7.908333
# 33   49.475000  134.766667  14.516667   6.908333
# 34   51.275000  139.250000  13.741667   6.775000
# 35   49.550000   38.244444  11.300000   5.583333
# 36   56.750000  133.300000  15.791667   6.958333

# %%
joined[cols].to_excel("joined.xlsx")

# %%
# Visualize joined data
import seaborn as sns
import matplotlib.pyplot as plt

def plot_scatter(happiness_rating):
    '''
    custom fucntion to plot several attributes against a
    specified happiness metric on a scatter plot
    '''
    rows = 2
    cols = 3
    fig, ax = plt.subplots(rows,cols)

    to_plot = ["rain_mm", "sun_hours", "tmax_degC", "tmin_degC","af_days"]
    plot_index = 0

    for row in range(0, rows):
        for col in range(0, cols):
        
            axes = ax[row][col]
            sns.scatterplot(data=joined, x=to_plot[plot_index], y=happiness_rating, ax=axes)
            axes.set_xlabel("")
            axes.set_xticklabels("")
            axes.set_yticklabels("")
            axes.set_title(to_plot[plot_index])
            plot_index += 1
        
            if plot_index >= len(to_plot):
                break

# %%
plot_scatter(happiness_rating="high_7_8")

# %%
to_plot = ["high_7_8", "af_days", "rain_mm", "sun_hours" , "tmax_degC","tmin_degC"]
sns.pairplot(joined[to_plot])

# %%
# Combine happiness data into two categories happy and unhappy

happy = joined.high_7_8 + joined.vhigh_9_10
happy.name = "happy"
unhappy = joined.low_0_4 + joined.medium_5_6
unhappy.name = "unhappy"

happiness_binary = pd.concat([joined,happy,unhappy], axis=1)
happiness_binary
# Out:
#       af_days area_codes                area_names  avg_rating  high_7_8  \
# 0    1.333333  W92000004                     WALES        7.44     39.45
# 1    2.750000  S92000003                  SCOTLAND        7.45     39.75
# 2    2.166667  S92000003                  SCOTLAND        7.45     39.75
# 3    3.333333  E12000003  YORKSHIRE AND THE HUMBER        7.41     38.56
# 4   10.083333  S92000003                  SCOTLAND        7.45     39.75
# 5    0.833333  E12000009                SOUTH WEST        7.50     40.44
# 6    2.916667  E12000006                      EAST        7.51     41.69
# 7    2.833333  W92000004                     WALES        7.44     39.45
# 8    1.833333  E12000009                SOUTH WEST        7.50     40.44
# 9         NaN  W92000004                     WALES        7.44     39.45
# 10   2.333333  S92000003                  SCOTLAND        7.45     39.75
# 11   4.083333  E12000001                NORTH EAST        7.34     39.06
# 12   1.000000  E12000007                    LONDON        7.38     42.20
# 13   7.000000  S92000003                  SCOTLAND        7.45     39.75
# 14   1.916667  E12000008                SOUTH EAST        7.54     40.88
# 15   4.166667  E12000009                SOUTH WEST        7.50     40.44
# 16   2.250000  S92000003                  SCOTLAND        7.45     39.75
# 17   5.000000  S92000003                  SCOTLAND        7.45     39.75
# 18   2.083333  E12000006                      EAST        7.51     41.69
# 19   1.416667  E12000006                      EAST        7.51     41.69
# 20   5.583333  S92000003                  SCOTLAND        7.45     39.75
# 21   5.250000  E12000002               NORTH WEST         7.39     39.10
# 22   2.666667  E12000008                SOUTH EAST        7.54     40.88
# 23   3.750000  S92000003                  SCOTLAND        7.45     39.75
# 24        NaN  E12000002               NORTH WEST         7.39     39.10
# 25   3.083333  E12000005             WEST MIDLANDS        7.43     41.72
# 26   4.416667  E12000005             WEST MIDLANDS        7.43     41.72
# 27   2.000000  E12000003  YORKSHIRE AND THE HUMBER        7.41     38.56
# 28        NaN  E12000008                SOUTH EAST        7.54     40.88
# 29   2.416667  S92000003                  SCOTLAND        7.45     39.75
# 30   2.833333  E12000004             EAST MIDLANDS        7.51     38.62
# 31   1.000000  S92000003                  SCOTLAND        7.45     39.75
# 32   2.000000  E12000002               NORTH WEST         7.39     39.10
# 33   2.833333  E12000004             EAST MIDLANDS        7.51     38.62
# 34   2.416667  E12000003  YORKSHIRE AND THE HUMBER        7.41     38.56
# 35   3.083333  S92000003                  SCOTLAND        7.45     39.75
# 36   3.333333  E12000009                SOUTH WEST        7.50     40.44
#
#     latitude  longitude  low_0_4  medium_5_6     rain_mm  sample_size  \
# 0       51.5       -3.2     9.56       16.54   83.683333        19540
# 1       56.0       -3.2     9.16       16.90   67.458333        22760
# 2       56.0       -3.2     9.16       16.90  103.833333        22760
# 3       53.6       -1.2    10.21       16.60   58.483333        13110
# 4       56.0       -3.2     9.16       16.90   71.308333        22760
# 5       51.0       -3.2     8.79       15.92   99.683333        13600
# 6       52.2        0.4     8.53       15.69   41.483333         9960
# 7       51.5       -3.2     9.56       16.54   99.300000        19540
# 8       51.0       -3.2     8.79       15.92   69.116667        13600
# 9       51.5       -3.2     9.56       16.54         NaN        19540
# 10      56.0       -3.2     9.16       16.90  143.941667        22760
# 11      55.0       -1.9    10.77       17.05   50.375000        11310
# 12      51.5       -0.1     8.32       18.30   68.800000        13560
# 13      56.0       -3.2     9.16       16.90  146.308333        22760
# 14      51.3       -0.5     7.97       15.83   48.333333        19490
# 15      51.0       -3.2     8.79       15.92   68.725000        13600
# 16      56.0       -3.2     9.16       16.90   88.875000        22760
# 17      56.0       -3.2     9.16       16.90   54.191667        22760
# 18      52.2        0.4     8.53       15.69   47.400000         9960
# 19      52.2        0.4     8.53       15.69   55.925000         9960
# 20      56.0       -3.2     9.16       16.90   41.775000        22760
# 21      54.0       -2.6    10.17       16.82   74.866667        19460
# 22      51.3       -0.5     7.97       15.83   50.516667        19490
# 23      56.0       -3.2     9.16       16.90   90.433333        22760
# 24      54.0       -2.6    10.17       16.82         NaN        19460
# 25      52.5       -2.3     8.61       17.59   62.541667        11940
# 26      52.5       -2.3     8.61       17.59   52.766667        11940
# 27      53.6       -1.2    10.21       16.60   66.516667        13110
# 28      51.3       -0.5     7.97       15.83         NaN        19490
# 29      56.0       -3.2     9.16       16.90   96.816667        22760
# 30      53.0       -0.8     8.66       16.74   44.683333         7880
# 31      56.0       -3.2     9.16       16.90  102.475000        22760
# 32      54.0       -2.6    10.17       16.82   72.766667        19460
# 33      53.0       -0.8     8.66       16.74   49.475000         7880
# 34      53.6       -1.2    10.21       16.60   51.275000        13110
# 35      56.0       -3.2     9.16       16.90   49.550000        22760
# 36      51.0       -3.2     8.79       15.92   56.750000        13600
#
#             station   sun_hours  tmax_degC  tmin_degC  vhigh_9_10  happy  \
# 0         aberporth  132.400000  13.166667   7.683333       34.45  73.90
# 1            armagh  114.141667  13.650000   6.033333       34.19  73.94
# 2      ballypatrick   35.252778  11.841667   6.016667       34.19  73.94
# 3          bradford  126.133333  13.741667   6.366667       34.63  73.19
# 4           braemar   29.852778  11.208333   2.908333       34.19  73.94
# 5          camborne  126.883333  14.241667   8.825000       34.84  75.28
# 6         cambridge   41.833333  15.425000   6.800000       34.09  75.78
# 7           cardiff   39.819444  15.433333   7.575000       34.45  73.90
# 8          chivenor   43.766667  15.200000   8.175000       34.84  75.28
# 9        cwmystwyth         NaN        NaN        NaN       34.45  73.90
# 10     dunstaffnage   32.313889  12.983333   6.425000       34.19  73.94
# 11           durham   37.355556  13.708333   5.908333       33.13  72.19
# 12       eastbourne  171.616667  15.016667   8.841667       31.18  73.38
# 13      eskdalemuir   94.375000  11.708333   4.016667       34.19  73.94
# 14         heathrow  142.066667  16.625000   8.300000       35.32  76.20
# 15             hurn  151.483333  15.916667   6.558333       34.84  75.28
# 16          lerwick  104.525000  10.083333   5.741667       34.19  73.94
# 17         leuchars  132.191667  12.883333   5.316667       34.19  73.94
# 18        lowestoft  162.933333  14.483333   7.775000       34.09  75.78
# 19          manston  158.566667  14.825000   7.991667       34.09  75.78
# 20            nairn  143.700000  12.750000   5.025000       34.19  73.94
# 21       newtonrigg   32.344444  13.066667   5.041667       33.91  73.01
# 22           oxford  150.141667  15.616667   7.450000       35.32  76.20
# 23          paisley  120.016667  13.050000   6.116667       34.19  73.94
# 24          ringway         NaN        NaN        NaN       33.91  73.01
# 25        rossonwye  142.766667  15.391667   6.983333       32.08  73.80
# 26         shawbury  125.158333  14.583333   6.025000       32.08  73.80
# 27        sheffield  126.475000  14.391667   7.233333       34.63  73.19
# 28      southampton         NaN        NaN        NaN       35.32  76.20
# 29        stornoway  104.466667  11.541667   6.058333       34.19  73.94
# 30  suttonbonington   40.402778  15.000000   6.916667       35.99  74.61
# 31            tiree  121.425000  11.925000   6.908333       34.19  73.94
# 32           valley  138.883333  13.641667   7.908333       33.91  73.01
# 33       waddington  134.766667  14.516667   6.908333       35.99  74.61
# 34           whitby  139.250000  13.741667   6.775000       34.63  73.19
# 35      wickairport   38.244444  11.300000   5.583333       34.19  73.94
# 36        yeovilton  133.300000  15.791667   6.958333       34.84  75.28
#
#     unhappy
# 0     26.10
# 1     26.06
# 2     26.06
# 3     26.81
# 4     26.06
# 5     24.71
# 6     24.22
# 7     26.10
# 8     24.71
# 9     26.10
# 10    26.06
# 11    27.82
# 12    26.62
# 13    26.06
# 14    23.80
# 15    24.71
# 16    26.06
# 17    26.06
# 18    24.22
# 19    24.22
# 20    26.06
# 21    26.99
# 22    23.80
# 23    26.06
# 24    26.99
# 25    26.20
# 26    26.20
# 27    26.81
# 28    23.80
# 29    26.06
# 30    25.40
# 31    26.06
# 32    26.99
# 33    25.40
# 34    26.81
# 35    26.06
# 36    24.71

# %%
# Plot Happy percentage
def plot_happy(feature):
    fig, ax = plt.subplots()
    sns.scatterplot(data=happiness_binary, x=feature, y="happy", ax=ax)
    
    
to_plot = ["af_days", "rain_mm", "sun_hours" , "tmax_degC","tmin_degC"]

for feature in to_plot:
    plot_happy(feature)

# %%
# Plot uhappy percentage
def plot_unhappy(feature):
    fig, ax = plt.subplots()
    sns.scatterplot(data=happiness_binary, x=feature, y="unhappy", ax=ax)
    
    
to_plot = ["af_days", "rain_mm", "sun_hours" , "tmax_degC","tmin_degC"]

for feature in to_plot:
    plot_unhappy(feature)

# %%
# Plot average happiness
def plot_avg_happiness(feature):
    fig, ax = plt.subplots()
    sns.scatterplot(data=happiness_binary, x=feature, y="avg_rating", ax=ax)
    
    
to_plot = ["af_days", "rain_mm", "sun_hours" , "tmax_degC","tmin_degC"]

for feature in to_plot:
    plot_avg_happiness(feature)

# %%
from scipy.stats import pearsonr
from sklearn.preprocessing import MinMaxScaler

def get_correlation(data, feature1, feature2):
    
    scaler = MinMaxScaler()
    h = data.drop(columns=["area_names", "area_codes", "station"]).dropna()

    x = np.array(h[feature1]).reshape(-1,1)
    scaler.fit(x)
    x = scaler.transform(x)

    y = np.array(h[feature2]).reshape(-1,1)
    scaler.fit(y)
    y = scaler.transform(y)

    return pearsonr(x,y)[0][0]

# %%
metrics = ["avg_rating", "happy", "unhappy"]
weather = ["af_days", "rain_mm", "sun_hours" , "tmax_degC","tmin_degC"]


for metric in metrics:
    for attribute in weather:
        coef = get_correlation(data=happiness_binary, feature1=attribute, feature2=metric)
        print(metric, attribute, coef)
# Out:
# avg_rating af_days -0.15106791808945497
# avg_rating rain_mm -0.1640643535100484
# avg_rating sun_hours 0.1534674106900967
# avg_rating tmax_degC 0.3795078111627864
# avg_rating tmin_degC 0.2639885873220659
# happy af_days -0.214234332828654
# happy rain_mm -0.21281367845313717
# happy sun_hours 0.2284051837217519
# happy tmax_degC 0.49422970951373585
# happy tmin_degC 0.38574880963450503
# unhappy af_days 0.21431673768081524
# unhappy rain_mm 0.21155041311433778
# unhappy sun_hours -0.22891057326142064
# unhappy tmax_degC -0.49418707093166214
# unhappy tmin_degC -0.3860785788245122
